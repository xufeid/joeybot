# %%
from supabase import create_client

SUPABASE_URL = "https://tphlwswgsxhpfaiuonee.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InRwaGx3c3dnc3hocGZhaXVvbmVlIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NDMxODc1MDksImV4cCI6MjA1ODc2MzUwOX0.RHRCPYd1TCqZAMTjRLXBE_Oua-TU3a0jNk6cOsxKmRQ"

supabase = create_client(SUPABASE_URL, SUPABASE_KEY)

# 查询数据库中的 "users" 表
response = supabase.table("wallets").select("*").execute()
print(response)
# Out:
# data=[{'id': 1, 'address': 'HwRnKq7RPtKHvX9wyHsc1zvfHtGjPQa5tyZtGtbvfXE', 'name': 'ufd聪'}, {'id': 2, 'address': 'C3nLTNMK6Ao1s3J1CQhv8GbT3NoMmifWoi9PGEcYd9hP', 'name': 'chenpepe'}, {'id': 3, 'address': 'CsD4m2ZUJahf7Cyb4yEeFxfr8bNMUCdXWUKicvK8AHAB', 'name': '疑似小松鼠'}, {'id': 4, 'address': 'E7pzx3SadstgrYztrBpPB9uNPX1y2dJFoNLKMNmTsu5f', 'name': 'swarms逃离2'}, {'id': 5, 'address': '2aTjYzEMjonqRroN8agxc1aBymgWwAWg1PR5auCziaH8', 'name': 'swawms逃离1'}, {'id': 6, 'address': 'Biz4tVqqnDT2FqG62cFdLimC6AsJMZHKg2SUahSNZwDT', 'name': '周牛牛小号2'}, {'id': 7, 'address': 'GpdgWB6SbNrphDapU2jmcwhMRkAUYaSP1LRCTeKC27kA', 'name': '周牛牛小号'}, {'id': 8, 'address': '687kTFNvKG9GXf8UsPzyrKbKpz5ExNrSCWfs7S4PTGiL', 'name': '高盈亏比的'}, {'id': 9, 'address': '5wTLevkkUWzKgRTWKcSjrgdoP8TnrEnXYGaAxFKibsS5', 'name': 'him'}, {'id': 10, 'address': '8JhckE5RX7pZno85WzGAPVdLfQ7po4MHmenwXzSockhx', 'name': 'him'}, {'id': 11, 'address': 'DxjmHXm1p7cs8Tezdf2EJm5xnwp9QC2E8CbfD1aXeH1j', 'name': 'him'}, {'id': 12, 'address': 'E737Z3
# ...

# %%
import pandas as pd

address_df = pd.read_excel('address_raw.xlsx')
address_df
# Out:
#     id                                       address                  name
# 0    1   HwRnKq7RPtKHvX9wyHsc1zvfHtGjPQa5tyZtGtbvfXE                  ufd聪
# 1    2  C3nLTNMK6Ao1s3J1CQhv8GbT3NoMmifWoi9PGEcYd9hP              chenpepe
# 2    3  CsD4m2ZUJahf7Cyb4yEeFxfr8bNMUCdXWUKicvK8AHAB                 疑似小松鼠
# 3    4  E7pzx3SadstgrYztrBpPB9uNPX1y2dJFoNLKMNmTsu5f             swarms逃离2
# 4    5  2aTjYzEMjonqRroN8agxc1aBymgWwAWg1PR5auCziaH8             swawms逃离1
# 5    6  Biz4tVqqnDT2FqG62cFdLimC6AsJMZHKg2SUahSNZwDT                周牛牛小号2
# 6    7  GpdgWB6SbNrphDapU2jmcwhMRkAUYaSP1LRCTeKC27kA                 周牛牛小号
# 7    8  687kTFNvKG9GXf8UsPzyrKbKpz5ExNrSCWfs7S4PTGiL                 高盈亏比的
# 8    9  5wTLevkkUWzKgRTWKcSjrgdoP8TnrEnXYGaAxFKibsS5                   him
# 9   10  8JhckE5RX7pZno85WzGAPVdLfQ7po4MHmenwXzSockhx                   him
# 10  11  DxjmHXm1p7cs8Tezdf2EJm5xnwp9QC2E8CbfD1aXeH1j                   him
# ...

# %%
columns_to_convert = ["address", "name"]  # 指定需要转换的列名
dict_list = address_df[columns_to_convert].to_dict(orient="records")
dict_list
# Out:
# [{'address': 'HwRnKq7RPtKHvX9wyHsc1zvfHtGjPQa5tyZtGtbvfXE', 'name': 'ufd聪'},
#  {'address': 'C3nLTNMK6Ao1s3J1CQhv8GbT3NoMmifWoi9PGEcYd9hP',
#   'name': 'chenpepe'},
#  {'address': 'CsD4m2ZUJahf7Cyb4yEeFxfr8bNMUCdXWUKicvK8AHAB', 'name': '疑似小松鼠'},
#  {'address': 'E7pzx3SadstgrYztrBpPB9uNPX1y2dJFoNLKMNmTsu5f',
#   'name': 'swarms逃离2'},
#  {'address': '2aTjYzEMjonqRroN8agxc1aBymgWwAWg1PR5auCziaH8',
#   'name': 'swawms逃离1'},
#  {'address': 'Biz4tVqqnDT2FqG62cFdLimC6AsJMZHKg2SUahSNZwDT', 'name': '周牛牛小号2'},
#  {'address': 'GpdgWB6SbNrphDapU2jmcwhMRkAUYaSP1LRCTeKC27kA', 'name': '周牛牛小号'},
#  {'address': '687kTFNvKG9GXf8UsPzyrKbKpz5ExNrSCWfs7S4PTGiL', 'name': '高盈亏比的'},
#  {'address': '5wTLevkkUWzKgRTWKcSjrgdoP8TnrEnXYGaAxFKibsS5', 'name': 'him'},
#  {'address': '8JhckE5RX7pZno85WzGAPVdLfQ7po4MHmenwXzSockhx', 'name': 'him'},
#  {'address': 'DxjmHXm1p7cs8Tezdf2EJm5xnwp9QC2E8CbfD1aXeH1j', 'name': 'him'},
#  {'address': 'E737Z3wRPfcrQ6YzTEbeXT8p1c8shd9vHZ74a3fLYCX7',
#   'name': 'vector的跟单号'},
# ...

# %%
response = supabase.table("wallets").insert(dict_list).execute()
print("批量插入成功：", response.data)
# Out:
# 批量插入成功： [{'id': 1, 'address': 'HwRnKq7RPtKHvX9wyHsc1zvfHtGjPQa5tyZtGtbvfXE', 'name': 'ufd聪'}, {'id': 2, 'address': 'C3nLTNMK6Ao1s3J1CQhv8GbT3NoMmifWoi9PGEcYd9hP', 'name': 'chenpepe'}, {'id': 3, 'address': 'CsD4m2ZUJahf7Cyb4yEeFxfr8bNMUCdXWUKicvK8AHAB', 'name': '疑似小松鼠'}, {'id': 4, 'address': 'E7pzx3SadstgrYztrBpPB9uNPX1y2dJFoNLKMNmTsu5f', 'name': 'swarms逃离2'}, {'id': 5, 'address': '2aTjYzEMjonqRroN8agxc1aBymgWwAWg1PR5auCziaH8', 'name': 'swawms逃离1'}, {'id': 6, 'address': 'Biz4tVqqnDT2FqG62cFdLimC6AsJMZHKg2SUahSNZwDT', 'name': '周牛牛小号2'}, {'id': 7, 'address': 'GpdgWB6SbNrphDapU2jmcwhMRkAUYaSP1LRCTeKC27kA', 'name': '周牛牛小号'}, {'id': 8, 'address': '687kTFNvKG9GXf8UsPzyrKbKpz5ExNrSCWfs7S4PTGiL', 'name': '高盈亏比的'}, {'id': 9, 'address': '5wTLevkkUWzKgRTWKcSjrgdoP8TnrEnXYGaAxFKibsS5', 'name': 'him'}, {'id': 10, 'address': '8JhckE5RX7pZno85WzGAPVdLfQ7po4MHmenwXzSockhx', 'name': 'him'}, {'id': 11, 'address': 'DxjmHXm1p7cs8Tezdf2EJm5xnwp9QC2E8CbfD1aXeH1j', 'name': 'him'}, {'id': 12, 'address': 'E73
# ...

# %%
import pandas as pd
response1 = supabase.table("txs").select("*").eq('account', 'Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd').execute()
response2 = supabase.table("txs").select("*").eq('account', 'FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8').execute()
# print(response)
df1 = pd.DataFrame(response1.data)
df2 = pd.DataFrame(response2.data)

# %%
df1
# Out:
#       id                                       account  \
# 0    985  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 1   1458  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 2   1671  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 3   1834  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 4   1840  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 5   2103  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 6   2104  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 7   2804  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 8   2806  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 9   2869  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 10  2948  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 11  3083  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
#
#                                 token_in_address  token_in_amount  \
# 0    So11111111111111111111111111111111111111112     1.000341e+01
# 1    VaxZxmFXV8tmsd72hUn22ex6GFzZ5uq9DVJ5wA5pump     2.869807e+05
# ...

# %%
df2
# Out:
#       id                                       account  \
# 0   1408  FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8
# 1   1476  FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8
# 2   2176  FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8
# 3   2203  FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8
# 4   2232  FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8
# 5   2450  FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8
# 6   2478  FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8
# 7   2913  FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8
# 8   2938  FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8
# 9   2949  FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8
# 10  2951  FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8
# 11  3035  FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8
#
#                                 token_in_address  token_in_amount  \
# 0    So11111111111111111111111111111111111111112     4.973657e+00
# 1   4Fy8Hsqg9SsSKTeYWT7QSS1MCyahEsuK64PMxsutpump     4.853893e+06
# ...

# %%
df3 = pd.concat([df1, df2], axis=0)
df3
# Out:
#       id                                       account  \
# 0    985  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 1   1458  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 2   1671  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 3   1834  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 4   1840  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 5   2103  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 6   2104  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 7   2804  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 8   2806  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 9   2869  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 10  2948  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 11  3083  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 0   1408  FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8
# 1   1476  FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8
# 2   2176  FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8
# 3   2203  FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8
# ...

# %%
df3[df3['token_out_address'] =='8BtoThi2ZoXnF7QQK1Wjmh2JuBw9FjVvhnGMVZ2vpump'][['account', 'token_out_address', 'created_at']]
# Out:
#                                          account  \
# 11  Gf9XgdmvNHt8fUTFsWAccNbKeyDXsgJyZN8iFJKg5Pbd
# 2   FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8
# 3   FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8
# 11  FbBba8W8EgHVkiQHKr5WFL689uohUdQcH5UZA3FasiK8
#
#                                token_out_address  \
# 11  8BtoThi2ZoXnF7QQK1Wjmh2JuBw9FjVvhnGMVZ2vpump
# 2   8BtoThi2ZoXnF7QQK1Wjmh2JuBw9FjVvhnGMVZ2vpump
# 3   8BtoThi2ZoXnF7QQK1Wjmh2JuBw9FjVvhnGMVZ2vpump
# 11  8BtoThi2ZoXnF7QQK1Wjmh2JuBw9FjVvhnGMVZ2vpump
#
#                           created_at
# 11  2025-04-08T07:36:43.431725+00:00
# 2   2025-04-04T18:22:44.876714+00:00
# 3   2025-04-04T21:13:11.923057+00:00
# 11   2025-04-08T02:57:00.12939+00:00
